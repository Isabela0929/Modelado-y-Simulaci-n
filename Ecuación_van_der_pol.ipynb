# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabela0929/Modelado-y-Simulaci-n/blob/main/Ecuaci%C3%B3n_van_der_pol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

def van_der_pol (t,y,mu):
 return [y[1],mu*(1-y[0]**2)*y[1]-y[0]]

def poincare_map (t,y)
tspan=[0,30]
y0=[0.5,0]
mu=1.5

solvdp = solve_ivp(van_der_pol,tspan, y0, args=(mu,),dense_output=True)

#print (solvdp.t)
#print (solvdp.y)
print(solvdp.t.size)
tplot=np.linspace(0,30,1000)
yplpt=solvdp.sol(tplot)
print(yplpt)

plt.plot(solvdp.t,solvdp.y[0])
plt.show()
# Out:
# 90
# [[ 0.5         0.499772    0.49907779 ... -1.84608661 -1.88313369
#   -1.91453576]
#  [ 0.         -0.01526928 -0.03104988 ... -1.33060984 -1.13660201
#   -0.95659584]]

# %%
plt.plot(yplpt[0],yplpt[1])
plt.show()

# %%
  print (solvdp)
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.996e-03 ...  2.981e+01  3.000e+01]
#         y: [[ 5.000e-01  5.000e-01 ... -1.605e+00 -1.915e+00]
#             [ 0.000e+00 -9.991e-04 ... -2.279e+00 -9.566e-01]]
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x7906ee68b320>
#  t_events: None
#  y_events: None
#      nfev: 758
#      njev: 0
#       nlu: 0
